# %%
import pandas as pd

# %%
pizza_8358 = pd.read_csv('8358_1.csv')
pizza_Datafiniti = pd.read_csv('Datafiniti_Pizza_Restaurants_and_the_Pizza_They_Sell_Jun19.csv')

# %%
pizza_8358.columns
# Out:
# Index(['id', 'address', 'categories', 'city', 'country', 'keys', 'latitude',
#        'longitude', 'menuPageURL', 'menus.amountMax', 'menus.amountMin',
#        'menus.currency', 'menus.dateSeen', 'menus.description', 'menus.name',
#        'name', 'postalCode', 'priceRangeCurrency', 'priceRangeMin',
#        'priceRangeMax', 'province'],
#       dtype='object')

# %%
new_cols_pizza_8358 = pizza_8358[['address', 'categories', 'city', 'country', 'latitude',
                                  'longitude', 'menus.amountMax', 'menus.amountMin',
                                  'menus.name','name', 'postalCode', 'province']]

# %%
new_cols_pizza_8358.head(1)
# Out:
#                                    address   categories  city country  \
# 0  Cascade Village Mall Across From Target  Pizza Place  Bend      US
#
#     latitude   longitude  menus.amountMax  menus.amountMin    menus.name  \
# 0  44.102665 -121.300797             22.5             15.5  Bianca Pizza
#
#                     name postalCode province
# 0  Little Pizza Paradise      97701       OR

# %%
pizza_Datafiniti.columns
# Out:
# Index(['id', 'dateAdded', 'dateUpdated', 'address', 'categories',
#        'primaryCategories', 'city', 'country', 'keys', 'latitude', 'longitude',
#        'menuPageURL', 'menus.amountMax', 'menus.amountMin', 'menus.currency',
#        'menus.dateSeen', 'menus.description', 'menus.name', 'name',
#        'postalCode', 'priceRangeCurrency', 'priceRangeMin', 'priceRangeMax',
#        'province'],
#       dtype='object')

# %%
pizza_Datafiniti.head(1)
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVz3Y-7h3D1zeR_xDAqm  2017-06-30T05:05:40Z  2019-05-01T15:43:09Z
#
#             address                                         categories  \
# 0  4203 E Kiehl Ave  Pizza,Restaurant,American restaurants,Pizza Pl...
#
#                primaryCategories      city country  \
# 0  Accommodation & Food Services  Sherwood      US
#
#                                        keys  latitude  ...  menus.currency  \
# 0  us/ar/sherwood/4203ekiehlave/-1051391616   34.8323  ...             USD
#
#                                       menus.dateSeen  menus.description  \
# 0  2018-05-01T04:25:37.197Z,2018-04-16T04:36:02.3...                NaN
#
#      menus.name                name postalCode priceRangeCurrency  \
# 0  Cheese Pizza  Shotgun Dans Pizza      72120                USD
#
#   priceRangeMin priceRangeMax province
# 0             0            25       AR
#
# [1 rows x 24 columns]

# %%
new_cols_pizza_Datafiniti= pizza_Datafiniti[['address', 'categories','primaryCategories','city', 'country',
                                             'latitude', 'longitude','menus.amountMax', 'menus.amountMin',
                                             'menus.name', 'name','postalCode', 'province']]

# %%
new_cols_pizza_Datafiniti.head(1)
# Out:
#             address                                         categories  \
# 0  4203 E Kiehl Ave  Pizza,Restaurant,American restaurants,Pizza Pl...
#
#                primaryCategories      city country  latitude  longitude  \
# 0  Accommodation & Food Services  Sherwood      US   34.8323   -92.1838
#
#    menus.amountMax  menus.amountMin    menus.name                name  \
# 0             7.98             7.98  Cheese Pizza  Shotgun Dans Pizza
#
#   postalCode province
# 0      72120       AR

# %%
new_cols_pizza_8358.count()
# Out:
# address            3510
# categories         3510
# city               3510
# country            3510
# latitude           3510
# longitude          3510
# menus.amountMax    2948
# menus.amountMin    2948
# menus.name         3510
# name               3510
# postalCode         3484
# province           3510
# dtype: int64

# %%
drop_pizza_8358 = new_cols_pizza_8358.dropna()

# %%
drop_pizza_8358.count()
# Out:
# address            2922
# categories         2922
# city               2922
# country            2922
# latitude           2922
# longitude          2922
# menus.amountMax    2922
# menus.amountMin    2922
# menus.name         2922
# name               2922
# postalCode         2922
# province           2922
# dtype: int64

# %%
new_cols_pizza_Datafiniti.count()
# Out:
# address              10000
# categories           10000
# primaryCategories    10000
# city                 10000
# country              10000
# latitude             10000
# longitude            10000
# menus.amountMax      10000
# menus.amountMin      10000
# menus.name           10000
# name                 10000
# postalCode            9996
# province             10000
# dtype: int64

# %%
drop_pizza_Datafiniti = new_cols_pizza_Datafiniti.dropna()

# %%
drop_pizza_Datafiniti.count()
# Out:
# address              9996
# categories           9996
# primaryCategories    9996
# city                 9996
# country              9996
# latitude             9996
# longitude            9996
# menus.amountMax      9996
# menus.amountMin      9996
# menus.name           9996
# name                 9996
# postalCode           9996
# province             9996
# dtype: int64

# %%
clean_pizza_8358 = drop_pizza_8358.rename(columns={
    'menus.amountMax':'menus max amount',
    'menus.amountMin':'menus min amount',
    'menus.name':'menus name',
    'postalCode':'postal code'
})

# %%
clean_pizza_8358.head()
# Out:
#                                    address                      categories  \
# 0  Cascade Village Mall Across From Target                     Pizza Place
# 1  Cascade Village Mall Across From Target                     Pizza Place
# 2                     148 S Barrington Ave  American Restaurant,Bar,Bakery
# 3                     148 S Barrington Ave  American Restaurant,Bar,Bakery
# 4                     148 S Barrington Ave  American Restaurant,Bar,Bakery
#
#           city country   latitude   longitude  menus max amount  \
# 0         Bend      US  44.102665 -121.300797             22.50
# 1         Bend      US  44.102665 -121.300797             18.95
# 2  Los Angeles      US  34.064563 -118.469017             12.00
# 3  Los Angeles      US  34.064563 -118.469017             13.00
# 4  Los Angeles      US  34.064563 -118.469017             13.00
#
#    menus min amount         menus name                   name postal code  \
# ...

# %%
drop_pizza_Datafiniti.head()
# Out:
#              address                                         categories  \
# 0   4203 E Kiehl Ave  Pizza,Restaurant,American restaurants,Pizza Pl...
# 1  25 E Camelback Rd                      Pizza,Pizza Place,Restaurants
# 2    3703 Paxton Ave                 Restaurant,Pizza Place,Restaurants
# 3    30495 John R Rd       Pizza,Carry-out food,Pizza Place,Restaurants
# 4   3600 Eastern Ave  Pizza,American restaurants,Pizza Place,Pizza e...
#
#                primaryCategories             city country   latitude  \
# 0  Accommodation & Food Services         Sherwood      US  34.832300
# 1  Accommodation & Food Services          Phoenix      US  33.509266
# 2  Accommodation & Food Services       Cincinnati      US  39.144883
# 3  Accommodation & Food Services  Madison Heights      US  42.516669
# 4  Accommodation & Food Services        Baltimore      US  39.286630
#
#     longitude  menus.amountMax  menus.amountMin    menus.name  \
# ...

# %%
clean_pizza_Datafiniti = drop_pizza_Datafiniti.rename(columns={
    'primaryCategories':'primary categories',
    'menus.amountMax':'menus max amount',
    'menus.amountMin':'menus min amount',
    'menus.name':'menus name',
    'postalCode':'postal code'
})

# %%
clean_pizza_Datafiniti.head()
# Out:
#              address                                         categories  \
# 0   4203 E Kiehl Ave  Pizza,Restaurant,American restaurants,Pizza Pl...
# 1  25 E Camelback Rd                      Pizza,Pizza Place,Restaurants
# 2    3703 Paxton Ave                 Restaurant,Pizza Place,Restaurants
# 3    30495 John R Rd       Pizza,Carry-out food,Pizza Place,Restaurants
# 4   3600 Eastern Ave  Pizza,American restaurants,Pizza Place,Pizza e...
#
#               primary categories             city country   latitude  \
# 0  Accommodation & Food Services         Sherwood      US  34.832300
# 1  Accommodation & Food Services          Phoenix      US  33.509266
# 2  Accommodation & Food Services       Cincinnati      US  39.144883
# 3  Accommodation & Food Services  Madison Heights      US  42.516669
# 4  Accommodation & Food Services        Baltimore      US  39.286630
#
#     longitude  menus max amount  menus min amount    menus name  \
# ...

# %%
clean_pizza_8358.to_csv(r'/Users/zackmccann/etl_project/pizza_8357.csv')
clean_pizza_Datafiniti.to_csv(r'/Users/zackmccann/etl_project/pizza_Datafiniti.csv')
